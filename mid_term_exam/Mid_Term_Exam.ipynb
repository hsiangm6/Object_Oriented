# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Question 1

# %% [markdown]
# ## load the data of WordsByCharacter
# - a. set the index by using column of 'Film', 'Chapter', 'Race', 'Character'
# - b. sort the index of Q1 a.
# - c. Access the character of the movie `The Fellowship Of The Ring` from its `first chapter`
# - d. how many words are spoken in the first chapter of the movie `The Fellowship Of The Ring`

# %%
# load data
WBC=pd.read_csv(r"WordsByCharacter.csv", encoding='utf8', engine='python')
WBC
# Out:
#                            Film                 Chapter  Character    Race  \
# 0    The Fellowship Of The Ring            01: Prologue      Bilbo  Hobbit
# 1    The Fellowship Of The Ring            01: Prologue     Elrond     Elf
# 2    The Fellowship Of The Ring            01: Prologue  Galadriel     Elf
# 3    The Fellowship Of The Ring            01: Prologue     Gollum  Gollum
# 4    The Fellowship Of The Ring  02: Concerning Hobbits      Bilbo  Hobbit
# ..                          ...                     ...        ...     ...
# 726      The Return Of The King     76: The Grey Havens     Elrond     Elf
# 727      The Return Of The King     76: The Grey Havens      Frodo  Hobbit
# 728      The Return Of The King     76: The Grey Havens  Galadriel     Elf
# 729      The Return Of The King     76: The Grey Havens    Gandalf   Ainur
# 730      The Return Of The King     76: The Grey Havens        Sam  Hobbit
#
#      Words
# 0        4
# 1        5
# 2      460
# 3       20
# 4      214
# ..     ...
# 726      6
# 727    132
# 728     17
# 729     42
# 730     14
#
# [731 rows x 5 columns]

# %%
# a. set the index by using column of 'Film', 'Chapter', 'Race', 'Character' 
index=pd.Series(WBC.columns)
index
# Out:
# 0         Film
# 1      Chapter
# 2    Character
# 3         Race
# 4        Words
# dtype: object

# %%
#Teacher Answer
multi=WBC.set_index(['Film', 'Chapter', 'Race', 'Charater'])
multi
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\hsian\Documents\GitHub\python\中山python課程\物件導向\mid_term_exam\Mid_Term_Exam.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/hsian/Documents/GitHub/python/%E4%B8%AD%E5%B1%B1python%E8%AA%B2%E7%A8%8B/%E7%89%A9%E4%BB%B6%E5%B0%8E%E5%90%91/mid_term_exam/Mid_Term_Exam.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> #Teacher Answer
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hsian/Documents/GitHub/python/%E4%B8%AD%E5%B1%B1python%E8%AA%B2%E7%A8%8B/%E7%89%A9%E4%BB%B6%E5%B0%8E%E5%90%91/mid_term_exam/Mid_Term_Exam.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> multi=WBC.set_index(['Film', 'Chapter', 'Race', 'Charater'])
#       <a href='vscode-notebook-cell:/c%3A/Users/hsian/Documents/GitHub/python/%E4%B8%AD%E5%B1%B1python%E8%AA%B2%E7%A8%8B/%E7%89%A9%E4%BB%B6%E5%B0%8E%E5%90%91/mid_term_exam/Mid_Term_Exam.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a> multi
#
# File c:\Users\hsian\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\hsian\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# KeyError: "None of ['Charater'] are in the columns"

# %%
# b. sort the index of Q1 a.
AfterSort=WBC.sort_index()
AfterSort
# Out:
#                            Film                 Chapter  Character    Race  \
# 0    The Fellowship Of The Ring            01: Prologue      Bilbo  Hobbit
# 1    The Fellowship Of The Ring            01: Prologue     Elrond     Elf
# 2    The Fellowship Of The Ring            01: Prologue  Galadriel     Elf
# 3    The Fellowship Of The Ring            01: Prologue     Gollum  Gollum
# 4    The Fellowship Of The Ring  02: Concerning Hobbits      Bilbo  Hobbit
# ..                          ...                     ...        ...     ...
# 726      The Return Of The King     76: The Grey Havens     Elrond     Elf
# 727      The Return Of The King     76: The Grey Havens      Frodo  Hobbit
# 728      The Return Of The King     76: The Grey Havens  Galadriel     Elf
# 729      The Return Of The King     76: The Grey Havens    Gandalf   Ainur
# 730      The Return Of The King     76: The Grey Havens        Sam  Hobbit
#
#      Words
# 0        4
# 1        5
# 2      460
# 3       20
# 4      214
# ..     ...
# 726      6
# 727    132
# 728     17
# 729     42
# 730     14
#
# [731 rows x 5 columns]

# %%
# c. Access the Character of the movie 'The Fellowship Of The Ring' from its 'first chapter'
condition=(WBC['Film']=='The Fellowship Of The Ring')&(WBC['Chapter']=='01: Prologue')
WBC['Character'][condition]
# Out:
# 0        Bilbo
# 1       Elrond
# 2    Galadriel
# 3       Gollum
# Name: Character, dtype: object

# %%
# d. how many words are spoken in the first chapter of the movie 'The Fellowship Of The Ring'
#np.sum(WBC[WBC['Film']=='The Fellowship Of The Ring']['Chapter']=='01: Prologue')
np.sum(WBC['Words'][(WBC['Film']=='The Fellowship Of The Ring')&(WBC['Chapter']=='01: Prologue')])
# Out:
# 489

# %% [markdown]
# # Question 2

# %% [markdown]
# ## Use the `planets` dataset form seaborn package
# - a. describe the `planets` dataset by excluding object datatype columns
# - b. describe int datatype columns of a `planets` Dataset
# - c. drop na on `planets` dataset, then describe that computes several common aggregates

# %%
# loading the 'planets' dataset form seaborn package
planets=sns.load_dataset('planets')
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
# a. describe the ``planets dataset`` by excluding object datatype columns
planets.describe(exclude='object')
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
# b. describe int datatype columns of a ``planets Dataset`` 
planets.describe(include='int')
# Out:
#             number         year
# count  1035.000000  1035.000000
# mean      1.785507  2009.070531
# std       1.240976     3.972567
# min       1.000000  1989.000000
# 25%       1.000000  2007.000000
# 50%       1.000000  2010.000000
# 75%       2.000000  2012.000000
# max       7.000000  2014.000000

# %%
# c. drop na on planets dataset, then describe that computes several common aggregates
planets.dropna().describe()
# Out:
#           number  orbital_period        mass    distance         year
# count  498.00000      498.000000  498.000000  498.000000   498.000000
# mean     1.73494      835.778671    2.509320   52.068213  2007.377510
# std      1.17572     1469.128259    3.636274   46.596041     4.167284
# min      1.00000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.00000       38.272250    0.212500   24.497500  2005.000000
# 50%      1.00000      357.000000    1.245000   39.940000  2009.000000
# 75%      2.00000      999.600000    2.867500   59.332500  2011.000000
# max      6.00000    17337.500000   25.000000  354.000000  2014.000000

# %% [markdown]
# # Question 3

# %% [markdown]
# ## Use US states population and abbreviations dataset
# - a. merge the data using many-to-one approach for the data of `pop` and `abbrevs`
# - b. remove the duplicate column whose values are common
# - c. check if there are any missing values in the merged dataset of `pop and abbrevs`

# %%
# reading the dataset
pop=pd.read_csv(r"state-population.csv", encoding='utf8', engine='python')
abbrev=pd.read_csv(r"state-abbrevs.csv", encoding='utf8', engine='python')

# %%
# a. merge the data using many-to-one approach for the data of pop and abbrevs

# Here the primary key is state/region (pop) and abbreviation (abbrevs)
# Using how='outer' so that no data is thrown away due to label mismatch
# The values in state/region and abbreviation are common however their column name are different
q4=pd.merge(pop, abbrev, left_on='state/region', right_on='abbreviation', how='outer')
q4
# Out:
#      state/region     ages  year   population    state abbreviation
# 0              AL  under18  2012    1117489.0  Alabama           AL
# 1              AL    total  2012    4817528.0  Alabama           AL
# 2              AL  under18  2010    1130966.0  Alabama           AL
# 3              AL    total  2010    4785570.0  Alabama           AL
# 4              AL  under18  2011    1125763.0  Alabama           AL
# ...           ...      ...   ...          ...      ...          ...
# 2539          USA    total  2010  309326295.0      NaN          NaN
# 2540          USA  under18  2011   73902222.0      NaN          NaN
# 2541          USA    total  2011  311582564.0      NaN          NaN
# 2542          USA  under18  2012   73708179.0      NaN          NaN
# 2543          USA    total  2012  313873685.0      NaN          NaN
#
# [2544 rows x 6 columns]

# %%
# b. remove the duplicate column whose values are common
# Dropping out the duplicate info
q4=pd.merge(pop, abbrev, left_on='state/region', right_on='abbreviation', how='outer').drop('abbreviation', axis=1)
q4
# Out:
#      state/region     ages  year   population    state
# 0              AL  under18  2012    1117489.0  Alabama
# 1              AL    total  2012    4817528.0  Alabama
# 2              AL  under18  2010    1130966.0  Alabama
# 3              AL    total  2010    4785570.0  Alabama
# 4              AL  under18  2011    1125763.0  Alabama
# ...           ...      ...   ...          ...      ...
# 2539          USA    total  2010  309326295.0      NaN
# 2540          USA  under18  2011   73902222.0      NaN
# 2541          USA    total  2011  311582564.0      NaN
# 2542          USA  under18  2012   73708179.0      NaN
# 2543          USA    total  2012  313873685.0      NaN
#
# [2544 rows x 5 columns]

# %%
# c. check if there are any missing values in the merged dataset of pop and abbrevs
q4.isnull()
# Out:
#       state/region   ages   year  population  state
# 0            False  False  False       False  False
# 1            False  False  False       False  False
# 2            False  False  False       False  False
# 3            False  False  False       False  False
# 4            False  False  False       False  False
# ...            ...    ...    ...         ...    ...
# 2539         False  False  False       False   True
# 2540         False  False  False       False   True
# 2541         False  False  False       False   True
# 2542         False  False  False       False   True
# 2543         False  False  False       False   True
#
# [2544 rows x 5 columns]

# %% [markdown]
# # Question 4

# %% [markdown]
# ## Use the dataset of world_population and answer below questions
# - a. how many continents do we have in the world?
# - b. what are the names of these continents?
# - c. how many countries are present in each continent?
# - d. what is the population (year 2022) of the world per continent?
# - e. what are the most five populous countries (year 2022) in the world?

# %%
# reading the dataset
world_pop=pd.read_csv(r"world_population.csv", encoding='utf8', engine='python')
world_pop
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# 2           44903225         43451666         39543154         35856344
# 3              44273            46189            51368            54849
# 4              79824            77700            71746            71519
# ..               ...              ...              ...              ...
# 229            11572            11655            12182            13142
# 230           575986           556048           491824           413296
# 231         33696614         32284046         28516545         24743946
# 232         20017675         18927715         16248230         13792086
# 233         16320537         15669666         14154937         12839771
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 0           19542982         10694796         12486631         10752971
# 1            3182021          3295066          2941651          2324731
# 2           30774621         25518074         18739378         13795915
# 3              58230            47818            32886            27075
# 4              66097            53569            35611            19860
# ..               ...              ...              ...              ...
# 229            14723            13454            11315             9377
# 230           270375           178529           116775            76371
# 231         18628700         13375121          9204938          6843607
# 232          9891136          7686401          5720438          4281671
# 233         11834676         10113893          7049926          5202918
#
#      Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 0        652230            63.0587       1.0257                         0.52
# 1         28748            98.8702       0.9957                         0.04
# 2       2381741            18.8531       1.0164                         0.56
# 3           199           222.4774       0.9831                         0.00
# 4           468           170.5641       1.0100                         0.00
# ..          ...                ...          ...                          ...
# 229         142            81.4930       0.9953                         0.00
# 230      266000             2.1654       1.0184                         0.01
# 231      527968            63.8232       1.0217                         0.42
# 232      752612            26.5976       1.0280                         0.25
# 233      390757            41.7665       1.0204                         0.20
#
# [234 rows x 17 columns]

# %%
# a. how many continents do we have in the world?
num_con=world_pop.groupby('Continent').sum()
name_con=pd.Series(num_con.index)
name_con.size
# Out:
# 6

# %%
# b. what are the names of these continents?
print(name_con)
# Out:
# 0           Africa
# 1             Asia
# 2           Europe
# 3    North America
# 4          Oceania
# 5    South America
# Name: Continent, dtype: object

# %%
# c. how many countries are present in each contin
world_pop.groupby(['Continent', 'Country/Territory']).sum()
# Out:
#                                  Rank  2022 Population  2020 Population  \
# Continent     Country/Territory
# Africa        Algeria              34         44903225         43451666
#               Angola               42         35588987         33428485
#               Benin                77         13352864         12643123
#               Botswana            144          2630296          2546402
#               Burkina Faso         58         22673762         21522626
# ...                               ...              ...              ...
# South America Paraguay            109          6780744          6618695
#               Peru                 44         34049588         33304756
#               Suriname            170           618040           607065
#               Uruguay             133          3422794          3429086
#               Venezuela            51         28301696         28490453
#
#                                  2015 Population  2010 Population  \
# Continent     Country/Territory
# Africa        Algeria                   39543154         35856344
#               Angola                    28127721         23364185
#               Benin                     10932783          9445710
#               Botswana                   2305171          2091664
#               Burkina Faso              18718019         16116845
# ...                                          ...              ...
# South America Paraguay                   6177950          5768613
#               Peru                      30711863         29229572
#               Suriname                    575475           546080
#               Uruguay                    3402818          3352651
#               Venezuela                 30529716         28715022
#
#                                  2000 Population  1990 Population  \
# Continent     Country/Territory
# Africa        Algeria                   30774621         25518074
#               Angola                    16394062         11828638
#               Benin                      6998023          5133419
#               Botswana                   1726985          1341474
#               Burkina Faso              11882888          9131361
# ...                                          ...              ...
# South America Paraguay                   5123819          4059195
#               Peru                      26654439         22109099
#               Suriname                    478998           412756
#               Uruguay                    3292224          3117012
#               Venezuela                 24427729         19750579
#
#                                  1980 Population  1970 Population  Area (km²)  \
# Continent     Country/Territory
# Africa        Algeria                   18739378         13795915     2381741
#               Angola                     8330047          6029700     1246700
#               Benin                      3833939          3023443      112622
#               Botswana                    938578           592244      582000
#               Burkina Faso               6932967          5611666      272967
# ...                                          ...              ...         ...
# South America Paraguay                   3078912          2408787      406752
#               Peru                      17492406         13562371     1285216
#               Suriname                    375112           379918      163820
#               Uruguay                    2953750          2790265      181034
#               Venezuela                 15210443         11355475      916445
#
#                                  Density (per km²)  Growth Rate  \
# Continent     Country/Territory
# Africa        Algeria                      18.8531       1.0164
#               Angola                       28.5466       1.0315
#               Benin                       118.5635       1.0274
#               Botswana                      4.5194       1.0162
#               Burkina Faso                 83.0641       1.0259
# ...                                            ...          ...
# South America Paraguay                     16.6705       1.0115
#               Peru                         26.4933       1.0099
#               Suriname                      3.7727       1.0082
#               Uruguay                      18.9069       0.9990
#               Venezuela                    30.8820       1.0036
#
#                                  World Population Percentage
# Continent     Country/Territory
# Africa        Algeria                                   0.56
#               Angola                                    0.45
#               Benin                                     0.17
#               Botswana                                  0.03
#               Burkina Faso                              0.28
# ...                                                      ...
# South America Paraguay                                  0.09
#               Peru                                      0.43
#               Suriname                                  0.01
#               Uruguay                                   0.04
#               Venezuela                                 0.35
#
# [234 rows x 13 columns]

# %%
# d. what is the population of the world per continent?
world_pop.groupby('Continent')['2022 Population'].sum()
# Out:
# Continent
# Africa           1426730932
# Asia             4721383274
# Europe            743147538
# North America     600296136
# Oceania            45038554
# South America     436816608
# Name: 2022 Population, dtype: int64

# %%
# e. what are the most five populous countries in the world
data_head=world_pop.set_index('Country/Territory')
data_head['2022 Population'].sort_values(ascending=False).head()
# Out:
# Country/Territory
# China            1425887337
# India            1417173173
# United States     338289857
# Indonesia         275501339
# Pakistan          235824862
# Name: 2022 Population, dtype: int64

# %%
data_tail=world_pop.set_index('Country/Territory')
data_tail['2022 Population'].sort_values(ascending=False).tail()
# Out:
# Country/Territory
# Montserrat          4390
# Falkland Islands    3780
# Niue                1934
# Tokelau             1871
# Vatican City         510
# Name: 2022 Population, dtype: int64
